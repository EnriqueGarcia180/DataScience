# %% [markdown]
# # <span style='color:black'> <center>Manejo de datos con Pandas</center> </span>
# ## 2. Análisis estadístico y agrupación
# <p><img src="https://online.york.ac.uk/wp-content/uploads/2021/07/man-in-a-suit-standing-behind-a-hologram-of-data-analytics-1030x579.jpg" width="750"</p>

# %% [markdown]
# ## Funciones estadísticas
# <p>A través de la estadística tenemos disponible una serie de medidas cuantitativas que nos permiten visualizar el comportamiento de una variable. Como ejemplo tenemos la media, mediana, mínimo, máxima y desviación estándar son estadísticas de resumen. El cálculo de estas nos permite tener una mejor comprensión y entendimiento de nuestro conjunto de datos, incluso si es muy grande.</p>

# %%
# Importar pandas y numpy

import pandas as pd
import numpy as np

# %%
# Importar el archivo csv sales a un DataFrame

df = pd.read_csv('sales.csv')
df
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 0          1    A           1  05/02/2018      24924.50       False
# 1          1    C           1  05/03/2018      21827.90       False
# 2          1    A           1  02/04/2018      57258.43       False
# 3          1    A           1  07/05/2018      17413.94       False
# 4          1    A           1  04/06/2018      17558.09       False
# ...      ...  ...         ...         ...           ...         ...
# 10769     39    C          99  09/12/2019        895.00       False
# 10770     39    A          99  03/02/2020        350.00       False
# 10771     39    A          99  08/06/2020        450.00       False
# 10772     39    A          99  13/07/2020          0.06       False
# 10773     39    A          99  05/10/2020        915.00       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment
# 0           5.727778              0.679451         8.106
# 1           8.055556              0.693452         8.106
# 2          16.816667              0.718284         7.808
# 3          22.527778              0.748928         7.808
# 4          27.050000              0.714586         7.808
# ...              ...                   ...           ...
# 10769       9.644444              0.834256         7.716
# 10770      15.938889              0.887619         7.244
# 10771      27.288889              0.911922         6.989
# 10772      25.644444              0.860145         6.623
# 10773      22.250000              0.955511         6.228
#
# [10774 rows x 9 columns]

# %%
# Imprimir las primeras 5 lineas de mi DataFrame

df.head(5)
# Out:
#    store type  department        date  weekly_sales  is_holiday  \
# 0      1    A           1  05/02/2018      24924.50       False
# 1      1    C           1  05/03/2018      21827.90       False
# 2      1    A           1  02/04/2018      57258.43       False
# 3      1    A           1  07/05/2018      17413.94       False
# 4      1    A           1  04/06/2018      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
# Imprimr la informacion de los campos de mi DataFrame

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10774 entries, 0 to 10773
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   store                 10774 non-null  int64
#  1   type                  10774 non-null  object
#  2   department            10774 non-null  int64
#  3   date                  10774 non-null  object
#  4   weekly_sales          10774 non-null  float64
#  5   is_holiday            10774 non-null  bool
#  6   temperature_c         10774 non-null  float64
#  7   fuel_price_usd_per_l  10774 non-null  float64
#  8   unemployment          10774 non-null  float64
# dtypes: bool(1), float64(4), int64(2), object(2)
# memory usage: 684.0+ KB

# %%
# Calcular el promedio de las venta semanales

df['weekly_sales'].mean()
# Out:
# 23843.95014850566

# %%
# Calcular la mediana de las ventas semanales

print(df['weekly_sales'].median())

# otra opcion
print(np.median(df['weekly_sales']))
# Out:
# 12049.064999999999
# 12049.064999999999

# %%
#Cambiamos a formato de fecha

df['date'] = pd.to_datetime(df['date'], dayfirst=True) # porque el primer dato es el dia (ver arriba en el df)

# Otra forma
df['date'] = pd.to_datetime(df['date'], format='d%/m%/y%')

# %%
# Calcular la última fecha de venta 

df['date'].max()
# Out:
# Timestamp('2020-10-26 00:00:00')

# %%
# Calcular la fecha en la que tuve mi primer venta

df['date'].min()
# Out:
# Timestamp('2018-02-05 00:00:00')

# %%
# notar como el formato de 'date' ya cambio

#was: object 
#is: datetime64[ns]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10774 entries, 0 to 10773
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   store                 10774 non-null  int64
#  1   type                  10774 non-null  object
#  2   department            10774 non-null  int64
#  3   date                  10774 non-null  datetime64[ns]
#  4   weekly_sales          10774 non-null  float64
#  5   is_holiday            10774 non-null  bool
#  6   temperature_c         10774 non-null  float64
#  7   fuel_price_usd_per_l  10774 non-null  float64
#  8   unemployment          10774 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 684.0+ KB

# %% [markdown]
# ## Multiples funciones
# <p>El método <code>.agg()</code> nos permite aplicar nuestras propias funciones personalizadas a un DataFrame, así como también aplicar funciones a más de una columna a la vez, lo que hace que los cálculos sean súper eficientes. Lo anterior se hace usando la siguiente nomenclatura: <code>df['columna'].agg([funcion1, funcion2])</code>
#
# En la función personalizada para este ejercicio, <code>IQR</code> nos muestra el rango intercuartil, que es el percentil 75 menos el percentil 25. Es una alternativa a la desviación estándar que resulta útil si sus datos contienen valores atípicos.</p>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Boxplot_vs_PDF.svg/1200px-Boxplot_vs_PDF.svg.png" width="450">

# %%
# Funcion IQR

def iqr(columna):
    calculo = columna.quantile(0.75) - columna.quantile(0.25)
    return calculo

# Calcular el IQR de la columna 'temperature_c' 

# una opcion:
# es aplicar funciones individualmente
print(iqr(df['temperature_c']))
print(np.mean(df['temperature_c']))

# otra opcion:
# Usando .agg() para usar mas de una funcion al mismo tiempo
df['temperature_c'].agg([iqr, np.mean])
# Out:
# 16.583333337000003
# 15.731978219306573
# C:\Users\egarcia\AppData\Local\Temp\ipykernel_12056\3626578906.py:16: FutureWarning: The provided callable <function mean at 0x00000230531C3B00> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df['temperature_c'].agg([iqr, np.mean])
# iqr     16.583333
# mean    15.731978
# Name: temperature_c, dtype: float64

# %%
# Calcula el IQR para 'temperature_c', 'fuel_price_usd_per_l', y 'unemployment'

df[['temperature_c', 'fuel_price_usd_per_l', 'unemployment']].agg(iqr)
# Out:
# temperature_c           16.583333
# fuel_price_usd_per_l     0.073176
# unemployment             0.565000
# dtype: float64

# %% [markdown]
# aplicar mas de una funcion a mas de una columna

# %%
# Agrega el promedio al cálculo anterior

df[['temperature_c', 'fuel_price_usd_per_l', 'unemployment']].agg([iqr, np.mean])
# Out:
# C:\Users\egarcia\AppData\Local\Temp\ipykernel_12056\3068979748.py:3: FutureWarning: The provided callable <function mean at 0x00000230531C3B00> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df[['temperature_c', 'fuel_price_usd_per_l', 'unemployment']].agg([iqr, np.mean])
# C:\Users\egarcia\AppData\Local\Temp\ipykernel_12056\3068979748.py:3: FutureWarning: The provided callable <function mean at 0x00000230531C3B00> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df[['temperature_c', 'fuel_price_usd_per_l', 'unemployment']].agg([iqr, np.mean])
# C:\Users\egarcia\AppData\Local\Temp\ipykernel_12056\3068979748.py:3: FutureWarning: The provided callable <function mean at 0x00000230531C3B00> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df[['temperature_c', 'fuel_price_usd_per_l', 'unemployment']].agg([iqr, np.mean])
#       temperature_c  fuel_price_usd_per_l  unemployment
# iqr       16.583333              0.073176      0.565000
# mean      15.731978              0.749746      8.082009

# %%
# Crea un nuevo DataFrame que contenga las ventas de la tienda 1 y el departamento 1

sales_1_1 = df[(df['store'] == 1) & (df['department'] == 1)]
sales_1_1
# Out:
#     store type  department       date  weekly_sales  is_holiday  \
# 0       1    A           1 2018-02-05      24924.50       False
# 1       1    C           1 2018-03-05      21827.90       False
# 2       1    A           1 2018-04-02      57258.43       False
# 3       1    A           1 2018-05-07      17413.94       False
# 4       1    A           1 2018-06-04      17558.09       False
# 5       1    A           1 2018-07-02      16333.14       False
# 6       1    A           1 2018-08-06      17508.41       False
# 7       1    C           1 2018-09-03      16241.78       False
# 8       1    A           1 2018-10-01      20094.19       False
# 9       1    A           1 2018-11-05      34238.88       False
# 10      1    A           1 2018-12-03      22517.56       False
# 11      1    A           1 2019-01-07      15984.24       False
#
#     temperature_c  fuel_price_usd_per_l  unemployment
# 0        5.727778              0.679451         8.106
# 1        8.055556              0.693452         8.106
# 2       16.816667              0.718284         7.808
# 3       22.527778              0.748928         7.808
# 4       27.050000              0.714586         7.808
# 5       27.172222              0.705076         7.787
# 6       30.644444              0.693980         7.787
# 7       27.338889              0.680772         7.787
# 8       22.161111              0.687640         7.838
# 9       14.855556              0.710359         7.838
# 10       9.594444              0.715378         7.838
# 11       9.038889              0.786176         7.742

# %%
# Ordena por fecha

sales_1_1 = sales_1_1.sort_values('date')

# Crea un nuevo campo calculando la venta acumulada semanal

sales_1_1['cum_weekly_sales'] = sales_1_1['weekly_sales'].cumsum()

# Crea un nuevo campo campo calculado con la venta acumulada máxima

sales_1_1['cum_max_sales'] = sales_1_1['weekly_sales'].cummax()

# Vamos a ver los campos que acabas de crear
sales_1_1[['date', 'weekly_sales', 'cum_weekly_sales', 'cum_max_sales']]
# Out:
#          date  weekly_sales  cum_weekly_sales  cum_max_sales
# 0  2018-02-05      24924.50          24924.50       24924.50
# 1  2018-03-05      21827.90          46752.40       24924.50
# 2  2018-04-02      57258.43         104010.83       57258.43
# 3  2018-05-07      17413.94         121424.77       57258.43
# 4  2018-06-04      17558.09         138982.86       57258.43
# 5  2018-07-02      16333.14         155316.00       57258.43
# 6  2018-08-06      17508.41         172824.41       57258.43
# 7  2018-09-03      16241.78         189066.19       57258.43
# 8  2018-10-01      20094.19         209160.38       57258.43
# 9  2018-11-05      34238.88         243399.26       57258.43
# 10 2018-12-03      22517.56         265916.82       57258.43
# 11 2019-01-07      15984.24         281901.06       57258.43

# %% [markdown]
# ## Eliminando duplicados de un DataFrame
# <p>Eliminar duplicados es una habilidad esencial para obtener análisis precisos porque, a menudo, no deseamos tener valores repetidos dentro de nuestros cálculos.</p>

# %%
# Elimina los duplicados de las combinaciones store/type

store_types = df.drop_duplicates(['store', 'type'])

# Resultado
store_types
# Out:
#        store type  department       date  weekly_sales  is_holiday  \
# 0          1    A           1 2018-02-05      24924.50       False
# 1          1    C           1 2018-03-05      21827.90       False
# 901        2    A           1 2018-02-05      35034.06       False
# 914        2    C           2 2018-03-05      68428.64       False
# 1798       4    A           1 2018-02-05      38724.42       False
# 2681       4    C          98 2018-07-02      13089.72       False
# 2699       6    A           1 2018-02-05      25619.00       False
# 2886       6    C          17 2018-09-03      16640.20       False
# 3593      10    B           1 2018-02-05      40212.84       False
# 4495      13    A           1 2018-02-05      46761.90       False
# 5130      13    C          59 2018-07-02        819.97       False
# 5408      14    A           1 2018-02-05      32842.31       False
# 6095      14    C          79 2018-04-02      46514.04       False
# 6293      19    A           1 2018-02-05      21500.58       False
# 7090      19    C          90 2018-12-03      66320.98       False
# 7199      20    A           1 2018-02-05      46021.21       False
# 8109      27    A           1 2018-02-05      32313.79       False
# 9009      31    A           1 2018-02-05      18187.71       False
# 9795      31    C          91 2018-06-04      68146.72       False
# 9899      39    A           1 2018-02-05      21244.50       False
# 10673     39    C          91 2018-08-06      59637.01       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment
# 0           5.727778              0.679451         8.106
# 1           8.055556              0.693452         8.106
# 901         4.550000              0.679451         8.324
# 914         8.427778              0.693452         8.324
# 1798        6.533333              0.686319         8.623
# 2681       23.144444              0.704811         7.372
# 2699        4.683333              0.679451         7.259
# 2886       27.861111              0.680772         6.973
# 3593       12.411111              0.782478         9.765
# 4495       -0.261111              0.704283         8.316
# 5130       26.011111              0.743381         7.951
# 5408       -2.605556              0.735455         8.992
# 6095        8.744444              0.752891         8.899
# 6293       -6.133333              0.780365         8.350
# 7090        2.577778              0.845351         8.067
# 7199       -3.377778              0.735455         8.187
# 8109       -2.672222              0.780365         8.237
# 9009        3.916667              0.679451         8.324
# 9795       28.155556              0.714586         8.200
# 9899        6.833333              0.679451         8.554
# 10673      29.400000              0.693980         8.360

# %%
# Elimina los duplicados de las combinaciones store/department y ordena por venta semanal

store_deps = df.drop_duplicates(['store', 'department']).sort_values('weekly_sales')

# Resultado
store_deps
# Out:
#        store type  department       date  weekly_sales  is_holiday  \
# 6806      19    A          47 2018-06-04        -70.00       False
# 3215       6    A          47 2018-02-05        -59.00       False
# 7900      20    A          77 2019-04-15        -29.97       False
# 9691      31    A          78 2018-02-05        -12.00       False
# 10103     39    A          19 2018-05-14        -11.00       False
# ...      ...  ...         ...        ...           ...         ...
# 1703       2    A          92 2018-02-05     178982.89       False
# 8017      20    A          92 2018-02-05     195223.84       False
# 6237      14    A          95 2018-02-05     213042.66       False
# 4271      10    B          72 2018-02-05     232558.51       False
# 6201      14    A          92 2018-02-05     293966.05       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment
# 6806       20.488889              0.794102         8.185
# 3215        4.683333              0.679451         7.259
# 7900       12.777778              1.009402         7.287
# 9691        3.916667              0.679451         8.324
# 10103      25.272222              0.753947         8.464
# ...              ...                   ...           ...
# 1703        4.550000              0.679451         8.324
# 8017       -3.377778              0.735455         8.187
# 6237       -2.605556              0.735455         8.992
# 4271       12.411111              0.782478         9.765
# 6201       -2.605556              0.735455         8.992
#
# [929 rows x 9 columns]

# %%
# Filtra las filas en donde las ventas hayan sido en días festivos ('is_holiday') y borra los duplicados de las fechas

holiday_dates = df[df['is_holiday'] == True].drop_duplicates('date')

# Resultado
holiday_dates
# Out:
#       store type  department       date  weekly_sales  is_holiday  \
# 498       1    A          45 2018-09-10         11.47        True
# 691       1    A          77 2019-11-25       1431.00        True
# 2315      4    A          47 2018-02-12        498.00        True
# 6735     19    A          39 2020-09-07         13.41        True
# 6810     19    A          47 2018-12-31       -449.00        True
# 6815     19    A          47 2020-02-10         15.00        True
# 6820     19    A          48 2019-09-09        197.00        True
#
#       temperature_c  fuel_price_usd_per_l  unemployment
# 498       25.938889              0.677602         7.787
# 691       15.633333              0.854861         7.866
# 2315      -1.755556              0.679715         8.623
# 6735      22.333333              1.076766         8.193
# 6810      -1.861111              0.881278         8.067
# 6815       0.338889              1.010723         7.943
# 6820      20.155556              1.038197         7.806

# %% [markdown]
# ## Conteo y proporción
# <p>Contar es una excelente manera de obtener una descripción general de nuestro conjunto datos y poder analizar sobre todo nuestras categorías top o en su defecto las que menor proporción tienen con respecto una variable</p>

# %%
# Contar el número de registros por cada tipo de tiendas (A, B y C)

df['type'].value_counts()
# Out:
# type
# A    9766
# B     902
# C     106
# Name: count, dtype: int64

# %%
# Dar la proporcion del cálculo anterior

df['type'].value_counts(normalize=True) * 100


# salen valores similares a los de la linea 90 abajo haciendo las ponderaciones manualmente

# Ojo, aqui la ponderacion es por el numero de ventas por tienda sin considerar el importe de las ventas. Solo cantidades de ventas.
# Out:
# type
# A    90.644143
# B     8.372007
# C     0.983850
# Name: proportion, dtype: float64

# %%
# Contar por tienda y ordenar el resultado

df['store'].value_counts(sort=True) # si es True ordena de acuerdo al Conteo. Si es false ordena de acuerdo a 'store'
# Out:
# store
# 13    913
# 20    910
# 19    906
# 10    902
# 1     901
# 4     901
# 27    900
# 2     897
# 6     894
# 31    890
# 14    885
# 39    875
# Name: count, dtype: int64

# %%
# Dar la proporción ordenada del cálculo anterior

df['store'].value_counts(normalize=True, sort=True) * 100   # *100 para ver ne porcentaje
# Out:
# store
# 13    8.474104
# 20    8.446260
# 19    8.409133
# 10    8.372007
# 1     8.362725
# 4     8.362725
# 27    8.353443
# 2     8.325599
# 6     8.297754
# 31    8.260627
# 14    8.214219
# 39    8.121403
# Name: proportion, dtype: float64

# %% [markdown]
# ## Porcentaje de ventas
# <p>Walmart distingue tres tipos de tiendas: "supercenters", "discount stores" y "neighborhood markets", codificados en este conjunto de datos como tipo "A", "B" y "C". En este ejercicio, vamos a calcular las ventas totales realizadas en cada tipo de tienda, sin utilizar <code>.groupby()</code>.</p>

# %%
# Calcular el total de ventas semanales

sales_all = df['weekly_sales'].sum()

# Calcular las ventas semanales para supercenters

sales_A = df[df['type'] == 'A']['weekly_sales'].sum()

# Calcular las ventas semanales para discount stores

sales_B = df[df['type'] == 'B']['weekly_sales'].sum()

# Calcular las ventas semanales para neighborhood markets

sales_C = df[df['type'] == 'C']['weekly_sales'].sum()

# Calcular la proporción de venta por tipo de tienda

print(sales_A / sales_all * 100)
print(sales_B / sales_all * 100)
print(sales_C / sales_all * 100)

# salen valores similares a los de la linea 87 arriba usando el metodo value_counts(normalize=true)
# aqui la poderacion es con base en el valor monetario de las ventas, no solo con cantidades de ventas por tienda
# Out:
# 89.97383152511354
# 9.022530314849538
# 1.0036381600369286

# %% [markdown]
# ## Group by
# <p> Podemos ahorrarnos mucho código usando el método <code>.groupby</code> como veremos a continuación</p>

# %%
# Calcular las ventas por tipo de tienda usando .groupby()

sales_by_type = df.groupby('type')['weekly_sales'].sum()

# Calcular la proporción

sales_by_type = sales_by_type / sales_all

# Resultado

sales_by_type * 100
# Out:
# type
# A    89.973832
# B     9.022530
# C     1.003638
# Name: weekly_sales, dtype: float64

# %%
# Para cada tipo de tienda calcular la venta mínima, máxima, el promedio y la media (Usar las funciones NumPy)

resultado = df.groupby('type')['weekly_sales'].agg(['min', 'max', 'mean', 'median'])

# Resultado
resultado
# Out:
#           min        max          mean     median
# type
# A    -1098.00  293966.05  23667.624573  11910.165
# B     -798.00  232558.51  25696.678370  13336.080
# C        0.01  104161.40  24323.522925  16643.205

# %%
# Para cada tipo de tienda, agrega los campos 'unemployment' y 'fuel_price_usd_per_l' y calcula el min, max, promedio y mediana

resultado2 = df.groupby('type')[['weekly_sales', 'unemployment', 'fuel_price_usd_per_l']].agg(['min', 'max', 'mean', 'median'])

# Resultado
resultado2
# Out:
#      weekly_sales                                     unemployment         \
#               min        max          mean     median          min    max
# type
# A        -1098.00  293966.05  23667.624573  11910.165        3.879  8.992
# B         -798.00  232558.51  25696.678370  13336.080        7.170  9.765
# C            0.01  104161.40  24323.522925  16643.205        6.858  8.899
#
#                       fuel_price_usd_per_l
#           mean median                  min       max      mean    median
# type
# A     7.974131  8.067             0.670997  1.107410  0.744943  0.735455
# B     9.279323  9.199             0.760023  1.107674  0.805858  0.803348
# C     7.832519  7.838             0.664129  0.921433  0.714793  0.710359

# %% [markdown]
# ## Pivot Tables
# <p> Las tablas dinámicas son la forma estándar de agregar datos en hojas de cálculo. En pandas, las tablas dinámicas son esencialmente otra forma de realizar cálculos agrupados. Es decir, el método <code>.pivot_table()</code> es justamente una alternativa a <code>.groupby()</code>.</p>

# %%
# Calcular el promedio de ventas semanales 'weekly_sales' por tipo de tienda con el metodo .pivot_table() 

pivote = pd.pivot_table(df,
                        values = 'weekly_sales',
                        index = 'type',
                        aggfunc = 'mean')

# Resultado
pivote
# Out:
#       weekly_sales
# type
# A     23667.624573
# B     25696.678370
# C     24323.522925

# %%
# Calcular el promedio y la mediana de ventas semanales por tipo de tienda 

pivote2 = pd.pivot_table(data=df,
                         values='weekly_sales',
                         index='type',
                         aggfunc=['mean', 'median'])

# Resultado
pivote2
# Out:
#               mean       median
#       weekly_sales weekly_sales
# type
# A     23667.624573    11910.165
# B     25696.678370    13336.080
# C     24323.522925    16643.205

# %%
# Calcular el promedio de ventas semanales por tipo de tienda y departamento

pivote3 = pd.pivot_table(data=df,
                         values='weekly_sales',
                         index='department',
                         columns='type',
                         aggfunc='mean')

# Resultado
pivote3
# Out:
# type                    A              B              C
# department
# 1            31145.215923   44050.626667   19034.840000
# 2            67736.748231  112958.526667   58721.845000
# 3            17124.044538   30580.655000   19497.300000
# 4            44265.151679   51219.654167   46937.810000
# 5            34942.639618   63236.875000   18887.710000
# ...                   ...            ...            ...
# 95          124084.721374   77082.102500  104161.400000
# 96           21184.264918    9528.538333   26941.770000
# 97           28503.679612    5828.873333   27077.523333
# 98           12952.719843     217.428333   10912.088000
# 99             377.993388            NaN     447.505000
#
# [80 rows x 3 columns]

# %%
# Calcular el promedio de ventas semanales por tipo de tienda y departamento, reemplazando los valores nulos con 0

pivote4 = pd.pivot_table(data=df,
                         values='weekly_sales',
                         index='department',
                         columns='type',
                         aggfunc=['mean','median'],
                         fill_value=0) # <- aqui se reemplazan los NaN por 0

# Resultado
pivote4
# Out:
#                      mean                                    median  \
# type                    A              B              C           A
# department
# 1            31145.215923   44050.626667   19034.840000   24780.020
# 2            67736.748231  112958.526667   58721.845000   68888.635
# 3            17124.044538   30580.655000   19497.300000   13396.805
# 4            44265.151679   51219.654167   46937.810000   42482.680
# 5            34942.639618   63236.875000   18887.710000   30363.630
# ...                   ...            ...            ...         ...
# 95          124084.721374   77082.102500  104161.400000  124022.940
# 96           21184.264918    9528.538333   26941.770000   24648.995
# 97           28503.679612    5828.873333   27077.523333   27150.780
# 98           12952.719843     217.428333   10912.088000   12815.020
# 99             377.993388       0.000000     447.505000     167.000
#
#
# type                 B           C
# department
# 1            31986.360   19034.840
# 2           112812.985   58721.845
# 3            23145.625   19497.300
# 4            51485.930   46937.810
# 5            60400.660   18887.710
# ...                ...         ...
# 95           76416.640  104161.400
# 96            9503.140   27144.895
# 97            5856.705   24082.800
# 98              34.100   11831.340
# 99               0.000     447.505
#
# [80 rows x 6 columns]

# %%
# Calcular el promedio de ventas semanales por tipo de tienda (A y B unicamente) y departamento, reemplazando los valores nulos con 0 y sumando las filas y columnas

pivote5 = pd.pivot_table(data=df[df['type'].isin(['A', 'B'])],
                         values='weekly_sales',
                         index='department',
                         columns='type',
                         aggfunc=['mean', 'median', 'sum'],
                         fill_value=0,
                         margins=True)

pivote5.to_csv('export_EXAMPLE_pivote5.csv')
pivote5.to_clipboard() # <- copia en Ctr+C - Ctrl+V

# Resultado
pivote5
# Out:
#                     mean                                  median              \
# type                   A              B           All          A           B
# department
# 1           31145.215923   44050.626667  32235.814014  24780.020   31986.360
# 2           67736.748231  112958.526667  71558.306972  68888.635  112812.985
# 3           17124.044538   30580.655000  18261.222887  13396.805   23145.625
# 4           44265.151679   51219.654167  44848.746294  42482.680   51485.930
# 5           34942.639618   63236.875000  37316.981049  30363.630   60400.660
# ...                  ...            ...           ...        ...         ...
# 96          21184.264918    9528.538333  20140.468507  24648.995    9503.140
# 97          28503.679612    5828.873333  26573.908865  27150.780    5856.705
# 98          12952.719843     217.428333  11853.270216  12815.020      34.100
# 99            377.993388       0.000000    377.993388    167.000       0.000
# All         23667.624573   25696.678370  23839.184990  11910.165   13336.080
#
#                                 sum
# type              All             A            B           All
# department
# 1           25660.830  4.048878e+06    528607.52  4.577486e+06
# 2           70208.070  8.805777e+06   1355502.32  1.016128e+07
# 3           13788.100  2.226126e+06    366967.86  2.593094e+06
# 4           43921.800  5.798735e+06    614635.85  6.413371e+06
# 5           30961.250  4.577486e+06    758842.50  5.336328e+06
# ...               ...           ...          ...           ...
# 96          23303.670  2.584480e+06    114342.46  2.698823e+06
# 97          26474.460  3.676975e+06     69946.48  3.746921e+06
# 98          11981.410  1.644995e+06      2609.14  1.647605e+06
# 99            167.000  4.573720e+04         0.00  4.573720e+04
# All         12033.555  2.311380e+08  23178403.89  2.543164e+08
#
# [81 rows x 9 columns]
